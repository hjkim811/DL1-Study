# %%
# Logistic Regression Classifier
import tensorflow as tf
import numpy as np
import random

# For reproducibility
def reset_seeds():
   tf.random.set_seed(2021)
   np.random.seed(2021)
   random.seed(2021)

x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

# %%
reset_seeds() # 이거 각 모델 앞에서 매번 넣어줘야 함, 안 넣으면 똑같은 결과 안 나옴

# model 1
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2)) # use sigmoid activation for 0~1 problem
tf.model.add(tf.keras.layers.Activation('sigmoid'))
# 위 두 줄 대신 아래 한 줄 써도 같은 결과 나옴, 대신 summary에서 activation 파트 안 뜸
# tf.model2.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))

# better result with loss function == 'binary_crossentropy', try 'mse' for yourself
# -> binary classification이어서 그런 듯
# adding accuracy metric to get accuracy report during training

tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()
history = tf.model.fit(x_data, y_data, epochs=500) # 5000에서 500으로 바꿈

# Accuracy report
print("Accuracy:", history.history['accuracy'][-1])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 997us/step - loss: 0.7587 - accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 999us/step - loss: 0.7385 - accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 999us/step - loss: 0.7200 - accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 998us/step - loss: 0.6878 - accuracy: 0.5000
# ...

# %%
# 앞에서 나온 model 이어서 학습시키기
tf.model.summary()
history = tf.model.fit(x_data, y_data, epochs=500)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 998us/step - loss: 0.4677 - accuracy: 0.8333
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4676 - accuracy: 0.8333
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4675 - accuracy: 0.8333
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8333
# Epoch 5/500
# 1/1 [==============================] - 0s 993us/step - loss: 0.4673 - accuracy: 0.8333
# Epoch 6/500
# ...

# %%
# 새로운 모델 만들기 (앞에서 만든 모델이랑 별개)

reset_seeds() # 이거 넣어줘야 같은 결과 나옴

# model 2
tf.model2 = tf.keras.Sequential()
tf.model2.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))
# use sigmoid activation for 0~1 problem

tf.model2.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model2.summary()
history = tf.model2.fit(x_data, y_data, epochs=500)

# Accuracy report
print("Accuracy: ", history.history['accuracy'][-1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 3
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 1/1 [==============================] - 0s 735us/step - loss: 0.7587 - accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7385 - accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7200 - accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 998us/step - loss: 0.7031 - accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6878 - accuracy: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 998us/step - loss: 0.6738 - accuracy: 0.5000
# Epoch 7/500
# ...

# %%
# Diabetes 데이터 이용
xy = np.loadtxt('csv/data-03-diabetes.csv', delimiter=',', dtype=np.float32)
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

print(x_data.shape, y_data.shape)
# Out:
# (759, 8) (759, 1)

# %%
tf.model = tf.keras.Sequential()
# multi-variable, x_data.shape[1] == feature counts == 8 in this case
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=x_data.shape[1], activation='sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01),  metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=500)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 9
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 24/24 [==============================] - 0s 753us/step - loss: 0.7242 - accuracy: 0.4967
# Epoch 2/500
# 24/24 [==============================] - 0s 871us/step - loss: 0.7147 - accuracy: 0.5257
# Epoch 3/500
# 24/24 [==============================] - 0s 776us/step - loss: 0.7068 - accuracy: 0.5652
# Epoch 4/500
# 24/24 [==============================] - 0s 790us/step - loss: 0.7000 - accuracy: 0.5784
# Epoch 5/500
# 24/24 [==============================] - 0s 703us/step - loss: 0.6942 - accuracy: 0.5955
# Epoch 6/500
# 24/24 [==============================] - 0s 706us/step - loss: 0.6892 - accuracy: 0.6126
# Epoch 7/500
# ...

# %%
# accuracy!
print("Accuracy: {0}".format(history.history['accuracy'][-1]))

# predict a single data point
y_predict = tf.model.predict([[0.176471, 0.155779, 0, 0, 0, 0.052161, -0.952178, -0.733333]])
print("Predict: {0}".format(y_predict)) # 결과가 0, 1로 나오지는 않음

# evaluating model
evaluate = tf.model.evaluate(x_data, y_data)
print("")
print("loss: {0}, accuracy: {1}".format(evaluate[0], evaluate[1]))
# Out:
# Accuracy: 0.7694334387779236
# Predict: [[0.59065074]]
# 24/24 [==============================] - 0s 664us/step - loss: 0.4787 - accuracy: 0.7694
#
# loss: 0.478662371635437, accuracy: 0.7694334387779236
